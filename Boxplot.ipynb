# %% [markdown]
# # Problem Statement

# %% [markdown]
# The box plot is common in data analysis for investigating individual numerical variables. In this project, you will investigate and investigate box plot and their uses. The box plot function from the Python package matplotlib.pyplot can be used to create box plots. Your submission should be in the form of a repositiory containing a Jupyter Notebook in which you detail your findings. In your notebook, you should:

# %% [markdown]
# ## References
#
# - http://vita.had.co.nz/papers/boxplots.pdf
# - https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
# - https://www.kaggle.com/kmuvunyi/iris-data-visualization
# - http://visualoop.com/blog/32470/a-look-at-box-plots
# - http://mathworld.wolfram.com/Box-and-WhiskerPlot.htm
# - http://vita.had.co.nz/papers/boxplots.pdf
# - https://www.r-statistics.com/2011/01/how-to-label-all-the-outliers-in-a-boxplot/
# - http://pirate.shu.edu/~wachsmut/Teaching/MATH1101/Descriptives/box.html
# - http://visualoop.com/blog/32470/a-look-at-box-plots
# - http://pirate.shu.edu/~wachsmut/Teaching/MATH1101/Descriptives/box.html
# - https://matplotlib.org/
# - https://matplotlib.org/gallery/statistics/boxplot_color.html

# %% [markdown]
# ### 1. Summarise the history of box plot and the situations in which it is used.

# %% [markdown]
# ### History of box plot

# %% [markdown]
# ![John Tukey](https://raw.githubusercontent.com/fionanealon/boxplot/master/img/John_Tukey.jpg)

# %% [markdown]
# Box plot otherwise know as the box and whisper plot was invented by John Tukey in 1969. The box plot is a histogram-like method of displaying data. [Ref: box and whisper](http://mathworld.wolfram.com/Box-and-WhiskerPlot.html) The box plot is a compact distributional summary, displaying less detail than a histogram or kernel density, but also taking up less space. They are particularly using for comparing distributions across groups. [Ref: History of box plot](http://vita.had.co.nz/papers/boxplots.pdf)
#
# Box plots are also a good method of determing and visualising outliers. Outliers are values that are much bigger or smaller than the rest of the data. When reviewing a boxplot, an outlier is defined as a data point that is located outside the fences (“whiskers”) of the boxplot (e.g: outside 1.5 times the interquartile range above the upper quartile and bellow the lower quartile) [Ref: Outliers](https://www.r-statistics.com/2011/01/how-to-label-all-the-outliers-in-a-boxplot/)

# %% [markdown]
# ![Distributions of boxplot](https://raw.githubusercontent.com/fionanealon/boxplot/master/img/skewness.png)

# %% [markdown]
# ### Symmetric

# %% [markdown]
# A box plot is symmetric if it's distribution is (approximately) normal. The mean and median should be similar. Most data points fall in the middle, there are few exceptionally small and few exceptionally large values. [Ref: Symmetric](http://pirate.shu.edu/~wachsmut/Teaching/MATH1101/Descriptives/box.html)

# %% [markdown]
# ### Positive skew

# %% [markdown]
# A box plot has a positive skew if distribution is shifted to the left. The mean should be less than median. Most data points fall to the left of the middle, there are more exceptionally small than exceptionally large values. [Ref: Positive skew](http://pirate.shu.edu/~wachsmut/Teaching/MATH1101/Descriptives/box.html)

# %% [markdown]
# ### Negative skew

# %% [markdown]
# A box plot has a negative skew if distribution is shifted to the right. The mean should be more than median. Most data points fall to the right of the middle, there are more exceptionally large than exceptionally small values. [Ref: Negative skew](http://pirate.shu.edu/~wachsmut/Teaching/MATH1101/Descriptives/box.html)

# %% [markdown]
# ### Variations of box plot

# %% [markdown]
# ![Variations](https://raw.githubusercontent.com/fionanealon/boxplot/master/img/variations.JPG)

# %% [markdown]
# ### Variable width box plot

# %% [markdown]
# Since John Tukey introduced this graphical representation of data, several variations of the traditoinal box plot has been described. [Ref: variations](https://en.wikipedia.org/wiki/Box_plot)
#
# Variable width box plots use the width of the box to represent the size of the data within each group. So a group with a larger total in the data will have a larger width. [Variable width box plots](http://visualoop.com/blog/32470/a-look-at-box-plots)

# %% [markdown]
# ### Notched box plot

# %% [markdown]
# Notched Box Plots have a narrowing of the box around the median. [Ref: Notched box plots](http://visualoop.com/blog/32470/a-look-at-box-plots)

# %% [markdown]
# ### Violin plot

# %% [markdown]
# Violin Plots are a pair of joined kernel density plot. [Ref: Violin plot](http://visualoop.com/blog/32470/a-look-at-box-plots)

# %% [markdown]
# ### Vase plot

# %% [markdown]
# This variation predates the Violin Plot in its application of density estimates, but only displays the middle section of its shape. [Ref: Vase plot](http://datavizcatalogue.com/blog/box-plot-variations/)

# %% [markdown]
# ### Bean plot

# %% [markdown]
# This variation takes its inspiration from nature and employs the use of the use of a Rug Plot AKA Barcode Plot and Density Plot to visualise the distribution of values. [Ref: Bean plot](http://datavizcatalogue.com/blog/box-plot-variations/)

# %% [markdown]
# ### Matplotlib and box plot

# %% [markdown]
# The matplotlib package and pyplot subpackage are graphics and plotting liraries in python are regularly used to produce plots and other two-dimensional data visualizations of numpy functions. The matplotlib package and pyplot subpackage are heavily dependent on the numerical functions within the numpy package. In order to produce these plotting functions, we need to import the matplotlib package and pyplot subpackage using the syntax import matplotlib.pyplot. Any function from the matplotlib package and pyplot subpackage can then be called as matplotlib.pyplot.function(). Matplotlib package and pyplot subpackage lines of code can be shortened if we import matplotlib and pyplot using the syntax import matplotlib.pyplot as plt. Any function from the matplotlib package and pyplot subpackage can then be called using the line of code plt.function(). [Ref: Matplotlib package](https://matplotlib.org/)
#
# The box plot function is a function contained within the matplotlib package. The box plot function produces box plot visualisations of numpy arrays. See below an example of matplotlib box plot function adapted from the matplotlib documentation. [Ref: Box plot function](https://matplotlib.org/gallery/statistics/boxplot_color.html)
#
# The example contains a graphical representation of two box plots - a rectangular box plot and a notched box plot. These have been plotted using the matplotlib.pyplot.subplot function. The rectangular box plot carries the traditional box plot shape while the notched box plot is narrowed around the median of the box plot. One hundred data points have been simuated in a standard normal distribution using the numpy.random.normal function. Using the numpy.random.seed function, I have set the seed of the data simulation. By setting the seed, I'll be able to predict the random numbers outputted by my function every time I call it. This is particularly useful for seed testing purposes.
#
# In each of the rectangular and notched box plot plots, matplotlib has plotted three box plots with a mean of around zero. x1 has an IQR of between 0.5 and -0.5. The maximum values of the distribution are around 2 and the minimum values are around -2. There is an outlier value of -3. x2 has an IQR of between 1.5 and -1.5. The maximum values of the distribution are around 4 and the minimum values are around -4. There is an outlier value of -6. x3 has an IQR of between 2.0 and -1.5. The maximum values of the distribution are around 6 and the minimum values are around -6.5. There are two outlier values of -7 and -7.5.

# %% [markdown]
# ### Simulate and visualise a box plot

# %%
# %matplotlib inline

# %%
# Pandas is Python package for analysing and manipluating dataframes
import pandas as pd
# Numpy is Python package for performing calculations on numerical arrays
import numpy as np 
# Seaborn is a Python package for creating plots.
import seaborn as sns
# Matplotlib is a Python package for creating plots.
import matplotlib as mpl 
# Pyplot is a graphical subpackage of matplotlib for creating plots.
import matplotlib.pyplot as plt

import scipy.stats as ss

# Set global parameter for using ggplot plotting style
plt.style.use('ggplot')
# Set the size of plots
plt.rcParams['figure.figsize'] = 14, 10

# %%
# Adatped from: https://matplotlib.org/gallery/statistics/boxplot_color.html

# Random test data
np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
labels = ['x1', 'x2', 'x3']

# Plot teh box plots using teh subplot function
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# rectangular box plot
bplot1 = axes[0].boxplot(all_data,
                         vert=True,  # vertical box alignment
                         patch_artist=True,  # fill with color
                         labels=labels)  # will be used to label x-ticks
axes[0].set_title('Rectangular box plot')

# notch shape box plot
bplot2 = axes[1].boxplot(all_data,
                         notch=True,  # notch shape
                         vert=True,  # vertical box alignment
                         patch_artist=True,  # fill with color
                         labels=labels)  # will be used to label x-ticks
axes[1].set_title('Notched box plot')

# fill with colors
colors = ['pink', 'lightblue', 'lightgreen']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

# adding horizontal grid lines
for ax in axes:
    ax.yaxis.grid(True)
    ax.set_xlabel('Three separate samples')
    ax.set_ylabel('Observed values')

plt.show()

# %% [markdown]
# ### 2. Demonstrate the use of box plot using data of your choosing.

# %% [markdown]
# ### Iris data set

# %% [markdown]
# ![Ronald Fischer](https://raw.githubusercontent.com/fionanealon/iris-data-set-project/master/Fischer.jpg)

# %% [markdown]
# One of the first multivariate data sets was introduced by British statiscian and biologist Ronald Fischer in 1936. This was named the Iris flower data set or Fisher's Iris data set. It is sometimes referred to as Anderson's Iris data set as it was Edgar Anderson who collected the data to quantify the botantical variations of Iris flowers of three related species. There are 150 rows of data in the data set and each row of the dataset represents an iris flower, including its species and dimensions of its botanical parts, sepal and petal, in centimeters. [Ref: Iris flower data set](https://en.wikipedia.org/wiki/Iris_flower_data_set)

# %% [markdown]
# ![Species](https://raw.githubusercontent.com/fionanealon/iris-data-set-project/master/iris.png)

# %% [markdown]
# The above image shows the three species contained in each class of the data set - Iris setosa, Iris virginica and Iris versicolor. The data set contains 50 samples each of these species with their botanical dimensions, sepal and petal, included in each row of the dataset.

# %% [markdown]
# ![sepalandpetal](https://raw.githubusercontent.com/fionanealon/iris-data-set-project/master/iris_with_labels.jpg)

# %% [markdown]
# Four features were measured from each sample: the length and the width of the sepals and petals, in centimetres. The sepal is described as a part of the flower with angiosperms (flowering plants). Sepals typically function as protection for the flower in bud, and often as support for the petals when in bloom. [Ref: Sepal](https://en.wikipedia.org/wiki/Iris_flower_data_set) Petals are described as modified leaves that surround the reproductive parts of flowers. [Ref: Petal](https://en.wikipedia.org/wiki/Petal)

# %% [markdown]
# ## Matplotib - the iris data set

# %% [markdown]
# Using the matplotlib plotting library, I have plotted the iris data set by using each of the sepal length, sepal width, petal length and petal width columns.

# %% [markdown]
# ### Sepal length

# %% [markdown]
# Sepal length has an IQR of between 6.4 and 5.1. It has a mean of 5.84. The maximum values of the distribution are around 7.9 and the minimum values are around 4.3. There are no outliers in the distribution.

# %% [markdown]
# ### Sepal width

# %% [markdown]
# Sepal width has an IQR of between 3.3 and 2.8. It has a mean of 3.05. The maximum values of the distribution are around 4.4 and the minimum values are around 2.0. There are otlier values of 2.0, 4.1, 4.2 and 4.4.

# %% [markdown]
# ### Petal length

# %% [markdown]
# Petal length has an IQR of between 5.1 and 1.6. It has a mean of 3.75. The maximum values of the distribution are around 6.9 and the minimum values are around 1.0. There are no otlier values in the distribution.

# %% [markdown]
# ### Petal width

# %% [markdown]
# ### Load data

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/fionanealon/datasets/master/irisnoid.csv')
iris.describe()
# Out:
#        sepal_length   sepal_width  petal_length  petal_width
# count     150.000000   150.000000    150.000000   150.000000
# mean        5.843333     3.054000      3.758667     1.198667
# std         0.828066     0.433594      1.764420     0.763161
# min         4.300000     2.000000      1.000000     0.100000
# 25%         5.100000     2.800000      1.600000     0.300000
# 50%         5.800000     3.000000      4.350000     1.300000
# 75%         6.400000     3.300000      5.100000     1.800000
# max         7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Visualise

# %%
# Call the boxplot function with an argument of the iris dataframe
iris.boxplot()

# Add title to plot
plt.title("Iris data set")

# Show the plot
plt.show()

# %% [markdown]
# ## Species

# %% [markdown]
# In the below plots, I have used matplotlib to plot box plots for each of the sepal length, sepal width, petal length and petal width columns by species.

# %% [markdown]
# ### Load Data

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/fionanealon/datasets/master/iris.csv')

# %% [markdown]
# ### Visualise

# %%
# Adapted from: https://www.kaggle.com/kmuvunyi/iris-data-visualization
iris.drop("id", axis=1).boxplot(by="species", figsize=(10, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027404539630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027404A436D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027404A69AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027404A92EB8>]],
#       dtype=object)

# %% [markdown]
# ### Seaborn - the iris data set

# %% [markdown]
# Seaborn is also a plotting library is python. It makes assumptions about the data set you wish to plot. By adding additional graphics to the plots you wish to plot, Seaborn provides a plotting library with far better aesthetics than matplotlib. It is also more efficient. See below boxplot of the iris data set by column from Seaborn. With a couple of lines of code, a far more visually appealing graphical reperesentation of the columns of the iris data set can be provided.

# %% [markdown]
# ### Load data

# %%
iris = sns.load_dataset("iris")

# %% [markdown]
# ### Visualise

# %%
# Adapted from https://seaborn.pydata.org/generated/seaborn.boxplot.html
ax = sns.boxplot(data=iris, orient="h", palette="Set2")

# %% [markdown]
# ### Box plots and histograms

# %% [markdown]
# In this section, I have used the boxplot and distplot functions from the Seaborn library to plot both a box plot and histogram for each of the columns of the data set. Both the box plot and the histogram are good methods of plotting a normal distribution. The histogram provides addiditional information about the spread of a data set by plotting the data using it's standard deviation.

# %% [markdown]
# ## Species

# %% [markdown]
# ### Visualise

# %%
# Adapted from: https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/
# Cut the window in 2 parts
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# Add a graph in each part
sns.boxplot(iris["sepal_length"], ax=ax_box)
sns.distplot(iris["sepal_length"], ax=ax_hist)
 
# Remove x axis name for the boxplotB
ax_box.set(xlabel='')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [Text(0.5,0,'')]

# %%
# Adapted from: https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/
# Cut the window in 2 parts
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# Add a graph in each part
sns.boxplot(iris["sepal_width"], ax=ax_box)
sns.distplot(iris["sepal_width"], ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [Text(0.5,0,'')]

# %%
# Adapted from: https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/
# Cut the window in 2 parts
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# Add a graph in each part
sns.boxplot(iris["petal_length"], ax=ax_box)
sns.distplot(iris["petal_length"], ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [Text(0.5,0,'')]

# %%
# Adapted from: https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/
# Cut the window in 2 parts
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# Add a graph in each part
sns.boxplot(iris["petal_width"], ax=ax_box)
sns.distplot(iris["petal_width"], ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [Text(0.5,0,'')]

# %% [markdown]
# ### 3. Explain any relevant terminology such as the terms quartile and percentile.

# %% [markdown]
# ![Boxplot](https://raw.githubusercontent.com/fionanealon/boxplot/master/img/boxplotterm.jpeg)

# %% [markdown]
# ### Five number summary of a data set

# %% [markdown]
# The box plot displays the five number summary of a data set - minimum, first quartile, median, third quartile and maximum.

# %% [markdown]
# ### Pandas

# %% [markdown]
# pandas.DataFrame.describe generates summary statistics of a dataframe. [Ref: describe](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html) These include the boxplot five number summary values. See below the summary staistics for the iris data set.

# %%
iris.describe()

# %% [markdown]
# ### Minimum

# %% [markdown]
# The minimum is the minimum sample value of a data set. See below the minimum values of the iris data set.

# %%
iris.min()

# %% [markdown]
# ### Quartiles divide the data points of data set into 4 equal parts:

# %% [markdown]
# ### First quartile

# %% [markdown]
# The first quartile is the 25th percentile of the data set. See below the first quartile values from the iris data set.

# %%
# Adapted from: https://stackoverflow.com/questions/45926230/how-to-calculate-1st-and-3rd-quartiles
iris.quantile([0.25])

# %% [markdown]
# ### Median

# %% [markdown]
# The median or otherwise known as the second quartile is the 50th percentile of the data set. See below the median values from the iris data set.

# %%
# Adapted from: https://stackoverflow.com/questions/45926230/how-to-calculate-1st-and-3rd-quartiles
iris.quantile([0.5])

# %% [markdown]
# ### Third quartile

# %% [markdown]
# The third quartile is the 75th percentile of the data set.

# %%
# Adapted from: https://stackoverflow.com/questions/45926230/how-to-calculate-1st-and-3rd-quartiles
iris.quantile([0.75])

# %% [markdown]
# ### Maximum

# %% [markdown]
# The maximum is the maximum sample value of a data set. See below the maximum values of the iris data set.

# %%
iris.max()

# %% [markdown]
# ### Other boxplot terminology

# %% [markdown]
# ### Interquartile range (IQR)

# %% [markdown]
# The interquartile range is equal to Q3 minus Q1. It is a measure based on variability. [Ref: IQR](https://stattrek.com/statistics/dictionary.aspx?definition=interquartile%20range)

# %% [markdown]
# ### Outlier

# %% [markdown]
# An outlier is an observation that lies an abnormal distance from other observations in a data set. [Ref: Outlier](https://www.itl.nist.gov/div898/handbook/prc/section1/prc16.htm)

# %% [markdown]
# ### Upper & lower fence

# %% [markdown]
# Upper and lower fences cordon off outliers from the bulk of data in a set. [Ref: Fence](https://www.statisticshowto.datasciencecentral.com/upper-and-lower-fences/) Fences are usually found with the following formulas:
#
# - Upper fence = Q3 + (1.5 * IQR)
# - Lower fence = Q1 – (1.5 * IQR).

# %% [markdown]
# ### Whisker

# %% [markdown]
# Whiskers are lines that spread from the two ends of the boxplot until they reach the sample maximum and minimum. [Ref: Whisker](http://web.pdx.edu/~stipakb/download/PA551/boxplot.html)

# %% [markdown]
# ### 4. Compare the box plot to alternatives.

# %% [markdown]
# In the additional to the histogram, see below additional plots used to represent a normal distribution.

# %% [markdown]
# ### Probability distribution

# %% [markdown]
# In the below probability distribtion, I have used the location and scale parameters to plot a normal distribution the four iris data variables. The location and scale parameters contain the mean and standard deviation for each of columns within the iris data set.

# %%
iris.mean()
# Out:
# id               75.500000
# sepal_length      5.843333
# sepal_width       3.054000
# petal_length      3.758667
# petal_width       1.198667
# dtype: float64

# %%
iris.std()
# Out:
# id               43.445368
# sepal_length      0.828066
# sepal_width       0.433594
# petal_length      1.764420
# petal_width       0.763161
# dtype: float64

# %% [markdown]
# ### Visualise

# %%
x = np.linspace(-10.0, 10.0, 1000)

plt.fill(x, ss.norm.pdf(x, loc= 5.84, scale=0.82), label="$\mu = 5.84, \sigma = 0.82$", c='b', alpha=0.6, lw=3.0)
plt.fill(x, ss.norm.pdf(x, loc= 3.05, scale=0.43), label="$\mu = 3.05, \sigma = 0.43$", c='r', alpha=0.6, lw=3.0)
plt.fill(x, ss.norm.pdf(x, loc= 3.75, scale=1.76), label="$\mu = 3.75, \sigma = 1.76$", c='g', alpha=0.6, lw=3.0)
plt.fill(x, ss.norm.pdf(x, loc= 1.19, scale=0.76), label="$\mu = 1.19, \sigma = 0.76$", c='y', alpha=0.6, lw=3.0)

plt.title("Normal distribution for different $\mu$ and $\sigma$")
plt.legend();

# %% [markdown]
# ### Probability density distribution

# %% [markdown]
# A probability distribution function or a probability density function is a continuous random variable, whose integral across an interval gives the probability that the value of the variable lies within the same interval. [Ref: Probability density funtion](https://en.wikipedia.org/wiki/Probability_density_function)
#
# For an normally distributed variable, irrespective of what the mean is and what the standard deviation is, if you start at the mean and move one standard deviation in either direction, the probability of measuring a value within this range of -1 to 1 is 68.27%. The probability of measuring a value within the range is -2 to 2 is 94.45%. The probability of measuring a value within the range is -3 to 3 is 99.73%.
#
# Probability density functions are useful in inferencial statistics where you don't know what the mean of a popluation is.

# %% [markdown]
# ### Visualise

# %%
x = np.linspace(-5.0, 5.0, 10000)
plt.plot(x, ss.norm.pdf(x, loc=0.0, scale=1.0), 'k-', lw=1.0)

xseg = x[np.logical_and(-5.0 <= x, x <= -3.0)]
plt.fill_between(xseg, ss.norm.pdf(xseg), color='y', alpha=0.5, linewidth=0)
xseg = x[np.logical_and(-3.0 <= x, x <= -2.0)]
plt.fill_between(xseg, ss.norm.pdf(xseg), color='r', alpha=0.5, linewidth=0)
xseg = x[np.logical_and(-2.0 <= x, x <= -1.0)]
plt.fill_between(xseg, ss.norm.pdf(xseg), color='g', alpha=0.5, linewidth=0)
xseg = x[np.logical_and(-1.0 <= x, x <=  1.0)]
plt.fill_between(xseg, ss.norm.pdf(xseg), color='b', alpha=0.5, linewidth=0, label="$1 \sigma = 68.27\%$")
xseg = x[np.logical_and( 1.0 <= x, x <=  2.0)]
plt.fill_between(xseg, ss.norm.pdf(xseg), color='g', alpha=0.5, linewidth=0, label="$2 \sigma = 95.45\%$")
xseg = x[np.logical_and( 2.0 <= x, x <=  3.0)]
plt.fill_between(xseg, ss.norm.pdf(xseg), color='r', alpha=0.5, linewidth=0, label="$3 \sigma = 99.73\%$")
xseg = x[np.logical_and( 3.0 <= x, x <=  5.0)]
plt.fill_between(xseg, ss.norm.pdf(xseg), color='y', alpha=0.5, linewidth=0)

plt.title("Normal Disribution - Probability Distribution Function")
plt.legend();

# %% [markdown]
# ### End
